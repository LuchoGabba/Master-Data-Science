# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchoGabba/master_data_science/blob/master/deep_learning/PyTorch.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>

# %% [markdown]
# # Tensores de PyTorch
#
# Los tensores son objetos de la clase ``torch.Tensor``.
